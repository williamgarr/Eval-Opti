# %% [markdown]
# # Graph generation examples
#
# ## Import the graph generation functions

# %%
import graph_gen
import networkx as nwx

# %% [markdown]
# ## Complete graph generation

# %%
complete_demand, complete_graph = graph_gen.gen_complete_graph(10)
nwx.draw(complete_graph, with_labels=True, font_weight='bold')
print(complete_demand)
# Out:
# [(4, 8, 959)]

# %% [markdown]
# ## Cyclic graph generation

# %%
cyclic_demand, cyclic_graph = graph_gen.gen_cyclic_graph(10)
nwx.draw(cyclic_graph, with_labels=True, font_weight='bold')
print(cyclic_demand)
# Out:
# [(4, 7, 950), (9, 7, 735), (2, 0, 179), (5, 8, 390)]

# %% [markdown]
# ## Random graph generation

# %%
random_demand, random_graph = graph_gen.gen_random_graph(10, 0.3)
nwx.draw(random_graph, with_labels=True, font_weight='bold')
print(random_demand)
# Out:
# [(3, 4, 12), (6, 1, 176), (7, 3, 119), (4, 3, 47), (7, 9, 730)]
